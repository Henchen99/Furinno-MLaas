# %% [markdown]
# <a href="https://colab.research.google.com/github/Henchen99/Furinno-MLaas/blob/main/Furinno_MLaaS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.style as style
from matplotlib import pyplot
from pandas.plotting import lag_plot

import datetime as dt
import matplotlib.dates as md
from datetime import date, time

# %%
sales_diagnostic_2018_9 = pd.read_excel('/content/drive/MyDrive/Furinno MLaaS/Sales Diagnostic (Monthly)/Sales Diagnostic_Detail View_US Shipped COGS 2018-09.xlsx')
sales_diagnostic_2018_10 = pd.read_excel('/content/drive/MyDrive/Furinno MLaaS/Sales Diagnostic (Monthly)/Sales Diagnostic_Detail View_US Shipped COGS 2018-10.xlsx')

# %%
sales_diagnostic_2018_9
# Out:
#     Program=[Amazon Retail]  \
# 0                      ASIN
# 1                B00OR1KQQ6
# 2                B00E3V3YX2
# 3                B0056NQV40
# 4                B00OR1KPL2
# ..                      ...
# 853              B004RHNYZ0
# 854              B004QXIFCC
# 855              B004QXID2Y
# 856              B004QXEGUW
# 857              B002NF61TE
#
#                       Distributor View=[Manufacturing]  \
# 0                                        Product Title
# 1         Furinno Simplistic End Table, Espresso/Black
# 2    Furinno Econ Multipurpose Home Office Computer...
# 3    FURINNO Efficient Home Laptop Notebook Compute...
# 4    Furinno Simplistic A Frame Computer Desk, Blac...
# ..                                                 ...
# 853  Furinno 3 Shelves Cabinet/Bedside Night Stand ...
# 854  Furinno Adjustable Vented Laptop Table Laptop ...
# 855  Furinno Easi Folding Multipurpose Tray Table, ...
# 856  Furinno Easi Folding Multipurpose Tray Table, ...
# ...

# %%
sales_diagnostic_daily_2021_07_01 = pd.read_csv('/content/drive/MyDrive/Furinno MLaaS/Sales Diagnostic (Daily)/2021/Amazon US Daily Sales Diagnostic (Shipped COGS)_2021-07-01.csv')

# %%
sales_diagnostic_daily_2021_07_01
# Out:
#            ASIN                                      Product Title  \
# 0    B074NH61RT                   Furinno 5-Cube Open Shelf, White
# 1    B01BWZWEAK  FURINNO JAYA Simple Home 3-Tier Adjustable She...
# 2    B07FL6D1Z8  FURINNO Just 3-Tier End Table, 1-Pack, French ...
# 3    B01K8JEEGS  FURINNO JAYA Large Entertainment Stand for TV ...
# 4    B074NHT1SM  Furinno 5-Tier Reversible Color Open Shelf Boo...
# ..          ...                                                ...
# 848  B003VP5Y4I  FURINNO Compact Computer Desk with Shelves, Ro...
# 849  B003VP22PC  Furinno 11191BK THE Entertainment Center TV St...
# 850  B003VP10PK      Furinno Simple Design End/SideTable, Espresso
# 851  B002NF61TE  Furinno Home Laptop Notebook Computer Desk, Li...
# 852  B002I9FV7I  Furinno Home Laptop Notebook Computer Desk, Bl...
#
#     Shipped COGS Shipped COGS - % of Total Shipped COGS - Prior Period  \
# 0      $6,036.10                     5.22%                      53.80%
# ...
